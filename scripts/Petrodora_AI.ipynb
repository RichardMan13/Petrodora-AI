# %%
# 1. Instalação com dependências completas
# !pip install --no-deps "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install unsloth_zoo
# !pip install --no-deps xformers==0.0.27 --index-url https://download.pytorch.org/whl/cu121
# !pip install trl peft accelerate bitsandbytes torchvision python-dotenv dagshub mlflow

# 2. Comando Ninja para corrigir o bitsandbytes (CUDA 13)
import os
import subprocess
try:
    cuda_path = subprocess.check_output(['find', '/usr/local', '-name', 'libnvJitLink.so.13']).decode('utf-8').strip().split('\n')[0]
    os.environ['LD_LIBRARY_PATH'] = os.environ.get('LD_LIBRARY_PATH', '') + ":" + "/".join(cuda_path.split("/")[:-1])
    print(f"CUDA 13 Registrado: {os.environ['LD_LIBRARY_PATH']}")
except:
    print("Falha ao localizar CUDA, mas tentando prosseguir...")

# 3. Teste se as libs estão "vivas"
import unsloth
import torchvision
import bitsandbytes
print("TUDO PRONTO! Pode rodar o treino.")

# %%
# Célula 2 (Nova): Clonagem e Setup
# !git clone https://github.com/RichardMan13/Omenortep-AI.git
# %cd Omenortep-AI
# Se você tiver o arquivo .env no Colab, mova para a pasta do projeto
import os
if os.path.exists('/content/.env'):
    # !mv /content/.env /content/Omenortep-AI/.env

# %%
# Célula 3 (Ajustada): Treino e Exportação
# !python scripts/train_phi3_omenortep.py
# !python scripts/export_gguf.py
# Out:
# [Errno 2] No such file or directory: 'Omenortep-AI'
# /content/Omenortep-AI
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# Unsloth: Your Flash Attention 2 installation seems to be broken. Using Xformers instead. No performance changes will be seen.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
#                       ❗❗❗ AUTHORIZATION REQUIRED ❗❗❗
#
#
# Open the following link in your browser to authorize the client:
# https://dagshub.com/login/oauth/authorize?state=595c576b-597b-409a-b982-d4d9e5e1a63f&client_id=32b60ba385aa7cecf24046d8195a71c07dd345d9657977863b52e7748e0f0f28&middleman_request_id=4704fba38b8c5ed489ed61087965b02ebfc3356d4cfb05a2995c28ca019ecbe6
#
#
# ⠏ Waiting for authorization
# Accessing as RichardMan13
# Initialized MLflow to track repo "RichardMan13/Omenortep-AI"
# Repository RichardMan13/Omenortep-AI initialized!
# ==((====))==  Unsloth 2026.3.10: Fast Mistral patching. Transformers: 5.3.0.
# ...

# %%
from google.colab import files
# Substitua o nome do arquivo se ele for ligeiramente diferente
files.download('/content/Omenortep-AI/models/GGUF-Export_gguf/phi-3-mini-4k-instruct.Q4_K_M.gguf')
